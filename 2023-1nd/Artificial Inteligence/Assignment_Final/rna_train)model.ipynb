# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.cluster import KMeans

import datetime

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score

from math import sqrt

from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# %%
clinical = pd.read_csv('./trainData/train_data_clinical_patient.csv', usecols=['PATIENT_ID', 'CANCER_TYPE_ACRONYM'])

# %%
clinical
# Out:
#         PATIENT_ID CANCER_TYPE_ACRONYM
# 0     TCGA-3M-AB46                STAD
# 1     TCGA-3M-AB47                STAD
# 2     TCGA-B7-5816                STAD
# 3     TCGA-B7-5818                STAD
# 4     TCGA-B7-A5TI                STAD
# ...            ...                 ...
# 2692  TCGA-WY-A85B                 LGG
# 2693  TCGA-WY-A85C                 LGG
# 2694  TCGA-WY-A85D                 LGG
# 2695  TCGA-WY-A85E                 LGG
# 2696  TCGA-R8-A6YH                 LGG
#
# [2697 rows x 2 columns]

# %%
first_df = pd.read_csv("./trainData/train_data_rna-seq.csv", encoding='utf-8')
first_df
# Out:
#       Hugo_Symbol  Entrez_Gene_Id  TCGA-3M-AB46-01  TCGA-3M-AB47-01  \
# 0             NaN       100130426              NaN              NaN
# 1             NaN       100133144          -0.6912          -0.4056
# 2             NaN       100134869          -0.0569          -1.1995
# 3             NaN           10357           0.7839          -0.0397
# 4             NaN           10431           2.6285           0.1811
# ...           ...             ...              ...              ...
# 20526      ZYG11A          440590           0.6274          -0.5807
# 20527      ZYG11B           79699           0.5821           0.3698
# 20528         ZYX            7791          -0.8533          -0.1465
# 20529       ZZEF1           23140          -1.6618          -0.0619
# 20530        ZZZ3           26009           0.2748           0.5492
#
#        TCGA-B7-5816-01  TCGA-B7-5818-01  TCGA-B7-A5TI-01  TCGA-B7-A5TJ-01  \
# 0                  NaN              NaN              NaN              NaN
# 1              -2.0249          -1.7479          -0.6720           0.2729
# 2              -0.5616           1.2902          -0.0517           0.1636
# 3              -2.7656          -1.0076           0.1231           1.2847
# 4              -0.2540          -0.2604           1.3377          -0.1858
# ...                ...              ...              ...              ...
# 20526          -1.4317          -1.4317          -0.8730          -0.7320
# 20527          -0.8969          -1.6536          -0.9848          -0.9928
# 20528          -0.0919           0.3913          -0.5291           0.1615
# 20529          -0.3589          -1.5988          -0.6019          -0.1565
# 20530          -1.4745          -2.7521           0.0214          -0.6957
#
#        TCGA-B7-A5TK-01  TCGA-B7-A5TN-01  ...  TCGA-VW-A8FI-01  \
# 0                  NaN              NaN  ...          -6.6197
# 1              -1.6346          -0.0469  ...           1.1529
# 2              -3.7799           0.0582  ...           0.7471
# 3               0.6795           0.6711  ...          -0.3517
# 4               1.2572           0.4134  ...          -0.3810
# ...                ...              ...  ...              ...
# 20526          -0.7461          -0.9315  ...           0.7317
# 20527           0.7091          -1.2326  ...          -1.3630
# 20528           0.8531           0.4881  ...           2.3670
# 20529          -1.6103          -1.1189  ...          -1.7330
# 20530          -0.6888          -0.8478  ...           0.1936
#
#        TCGA-W9-A837-01  TCGA-WH-A86K-01  TCGA-WY-A858-01  TCGA-WY-A859-01  \
# 0              -6.6197          -6.6197          -6.6197          -6.6197
# 1               0.5938           0.4161          -0.0182          -1.0264
# 2               1.0861           0.0440           0.2981          -0.4821
# 3              -0.8943           1.0942           0.7643          -0.4045
# 4              -0.1261          -0.3370           0.7580           1.2928
# ...                ...              ...              ...              ...
# 20526          -1.2143          -1.2143          -0.4660           0.1100
# 20527           0.1147           0.0871          -0.9503           0.8521
# 20528          -1.0349          -0.1840           0.3662          -0.4420
# 20529           0.2662          -0.5119          -0.9516          -0.6513
# 20530          -0.8139           0.2671          -0.4662          -0.2335
#
#        TCGA-WY-A85A-01  TCGA-WY-A85B-01  TCGA-WY-A85C-01  TCGA-WY-A85D-01  \
# 0              -6.6197          -6.6197          -6.6197          -6.6197
# 1              -0.4623           0.0507           0.4778          -0.4763
# 2               0.2481           0.5676           0.4846          -0.6968
# 3              -0.4197          -0.2125          -0.5183          -0.8822
# 4               0.2058           0.2314          -0.6588           0.4685
# ...                ...              ...              ...              ...
# 20526          -1.2143          -0.2231           0.9422          -1.2143
# 20527           0.4425           0.3485           1.0692          -0.1277
# 20528          -0.9402          -0.8402          -0.4389          -0.6813
# 20529          -0.1893           0.1042           0.7413          -0.5001
# 20530           0.4236           1.0122           1.2262           0.8035
#
#        TCGA-WY-A85E-01
# 0              -6.6197
# 1               0.2876
# 2              -0.9707
# 3              -0.0090
# 4               0.6967
# ...                ...
# 20526           1.1519
# 20527           0.7383
# 20528          -0.3227
# 20529          -0.4875
# 20530           0.2730
#
# [20531 rows x 2765 columns]

# %%
#Nan제거
second_df = first_df.dropna(subset=['Hugo_Symbol'])
second_df = second_df.reset_index(drop=True)
second_df
# Out:
#       Hugo_Symbol  Entrez_Gene_Id  TCGA-3M-AB46-01  TCGA-3M-AB47-01  \
# 0            A1BG               1           0.2076           0.4276
# 1            A1CF           29974          -1.0518           0.5072
# 2           A2BP1           54715          -0.8329           2.1122
# 3           A2LD1           87769           1.2071           0.6262
# 4             A2M               2          -0.7818           0.9275
# ...           ...             ...              ...              ...
# 20497      ZYG11A          440590           0.6274          -0.5807
# 20498      ZYG11B           79699           0.5821           0.3698
# 20499         ZYX            7791          -0.8533          -0.1465
# 20500       ZZEF1           23140          -1.6618          -0.0619
# 20501        ZZZ3           26009           0.2748           0.5492
#
#        TCGA-B7-5816-01  TCGA-B7-5818-01  TCGA-B7-A5TI-01  TCGA-B7-A5TJ-01  \
# 0              -0.9922          -1.0179          -0.4527          -0.5642
# 1              -2.1072          -2.1278           0.6810           1.2261
# 2              -1.0945          -1.0945          -1.0945          -0.1976
# 3               0.3858          -2.6991           0.8135           2.8214
# 4              -0.4149          -1.2313           0.4039          -0.7086
# ...                ...              ...              ...              ...
# 20497          -1.4317          -1.4317          -0.8730          -0.7320
# 20498          -0.8969          -1.6536          -0.9848          -0.9928
# 20499          -0.0919           0.3913          -0.5291           0.1615
# 20500          -0.3589          -1.5988          -0.6019          -0.1565
# 20501          -1.4745          -2.7521           0.0214          -0.6957
#
#        TCGA-B7-A5TK-01  TCGA-B7-A5TN-01  ...  TCGA-VW-A8FI-01  \
# 0               0.5899          -0.1583  ...           0.8868
# 1              -1.1916          -0.5322  ...          -2.3298
# 2              -1.0945          -1.0945  ...          -1.1720
# 3              -1.3555           0.3870  ...           1.4632
# 4               1.1713           0.4539  ...          -0.6719
# ...                ...              ...  ...              ...
# 20497          -0.7461          -0.9315  ...           0.7317
# 20498           0.7091          -1.2326  ...          -1.3630
# 20499           0.8531           0.4881  ...           2.3670
# 20500          -1.6103          -1.1189  ...          -1.7330
# 20501          -0.6888          -0.8478  ...           0.1936
#
#        TCGA-W9-A837-01  TCGA-WH-A86K-01  TCGA-WY-A858-01  TCGA-WY-A859-01  \
# 0              -1.4281           2.0103           1.3660          -0.1550
# 1              -2.3298          -2.3298          -2.3298          -2.3298
# 2               1.3013          -0.5875          -2.0743           1.7416
# 3              -0.3344           0.2268           0.3680          -0.4358
# 4              -0.9471           0.2347           2.3168          -1.4888
# ...                ...              ...              ...              ...
# 20497          -1.2143          -1.2143          -0.4660           0.1100
# 20498           0.1147           0.0871          -0.9503           0.8521
# 20499          -1.0349          -0.1840           0.3662          -0.4420
# 20500           0.2662          -0.5119          -0.9516          -0.6513
# 20501          -0.8139           0.2671          -0.4662          -0.2335
#
#        TCGA-WY-A85A-01  TCGA-WY-A85B-01  TCGA-WY-A85C-01  TCGA-WY-A85D-01  \
# 0               0.0365           0.1544           0.6591           1.8078
# 1              -2.3298          -2.3298          -0.2885          -2.3298
# 2               0.0690          -0.8346          -0.8072          -1.1571
# 3              -0.0906           0.0154          -0.3613          -0.9304
# 4              -0.3067           0.8500          -0.0253           0.0875
# ...                ...              ...              ...              ...
# 20497          -1.2143          -0.2231           0.9422          -1.2143
# 20498           0.4425           0.3485           1.0692          -0.1277
# 20499          -0.9402          -0.8402          -0.4389          -0.6813
# 20500          -0.1893           0.1042           0.7413          -0.5001
# 20501           0.4236           1.0122           1.2262           0.8035
#
#        TCGA-WY-A85E-01
# 0               0.6973
# 1              -2.3298
# 2               0.8931
# 3              -1.1419
# 4              -1.1735
# ...                ...
# 20497           1.1519
# 20498           0.7383
# 20499          -0.3227
# 20500          -0.4875
# 20501           0.2730
#
# [20502 rows x 2765 columns]

# %%
first_df[['TCGA-BR-4280-01']]
# Out:
#        TCGA-BR-4280-01
# 0                  NaN
# 1              -0.0802
# 2              -0.1003
# 3               0.9334
# 4               0.9662
# ...                ...
# 20526          -1.2122
# 20527          -0.9524
# 20528          -0.7196
# 20529           0.3103
# 20530           0.9266
#
# [20531 rows x 1 columns]

# %%
second_df = second_df.drop(['Hugo_Symbol'],axis=1)

second_df=second_df.transpose()

second_df = second_df.rename(columns=second_df.iloc[0])

second_df.index = second_df.index.str.rstrip('-01')

second_df = second_df.drop(second_df.index[0])
second_df
# Out:
#               1.0       29974.0   54715.0   87769.0   2.0       144568.0  \
# TCGA-3M-AB46    0.2076   -1.0518   -0.8329    1.2071   -0.7818   -0.8253
# TCGA-3M-AB47    0.4276    0.5072    2.1122    0.6262    0.9275   -0.6354
# TCGA-B7-5816   -0.9922   -2.1072   -1.0945    0.3858   -0.4149   -0.4633
# TCGA-B7-5818   -1.0179   -2.1278   -1.0945   -2.6991   -1.2313    0.8780
# TCGA-B7-A5TI   -0.4527    0.6810   -1.0945    0.8135    0.4039    0.6896
# ...                ...       ...       ...       ...       ...       ...
# TCGA-WY-A85A    0.0365   -2.3298    0.0690   -0.0906   -0.3067    0.9726
# TCGA-WY-A85B    0.1544   -2.3298   -0.8346    0.0154    0.8500   -0.8925
# TCGA-WY-A85C    0.6591   -0.2885   -0.8072   -0.3613   -0.0253   -0.9871
# TCGA-WY-A85D    1.8078   -2.3298   -1.1571   -0.9304    0.0875    0.8196
# TCGA-WY-A85E    0.6973   -2.3298    0.8931   -1.1419   -1.1735    0.4283
#
#               53947.0   51146.0   404744.0  8086.0    ...  55055.0   11130.0   \
# TCGA-3M-AB46   -0.9673   -1.5546    0.7883    0.0646  ...    1.2552    2.6983
# TCGA-3M-AB47    0.4636   -1.0286   -1.4886   -0.5795  ...    0.1266   -0.5029
# TCGA-B7-5816    1.1193    0.3950   -0.7351   -0.6825  ...   -0.9013    0.1416
# TCGA-B7-5818   -0.5319    1.9559   -1.4886   -0.0726  ...   -1.4085    0.7458
# TCGA-B7-A5TI   -0.0799    1.5994   -0.1381    0.0263  ...    0.3886    1.0328
# ...                ...       ...       ...       ...  ...       ...       ...
# TCGA-WY-A85A   -0.7398   -0.6719   -1.3060    0.8323  ...   -0.5834   -0.4914
# TCGA-WY-A85B   -1.0079    0.9052   -1.3060   -0.0945  ...    1.0486    1.1282
# TCGA-WY-A85C    0.1267    0.3564   -1.3060    0.8454  ...   -0.6817   -0.7663
# TCGA-WY-A85D   -0.3884   -1.8299   -1.3060    0.9347  ...   -1.9247   -0.3125
# TCGA-WY-A85E   -1.5843   -1.8299   -0.5086    0.4441  ...    0.8830    1.1751
#
#               7789.0    158586.0  79364.0   440590.0  79699.0   7791.0    \
# TCGA-3M-AB46   -1.0061   -0.4243   -1.1151    0.6274    0.5821   -0.8533
# TCGA-3M-AB47   -1.1278    0.6149   -0.7507   -0.5807    0.3698   -0.1465
# TCGA-B7-5816   -0.0425   -0.9111   -1.1933   -1.4317   -0.8969   -0.0919
# TCGA-B7-5818   -2.5996   -5.5211    1.3570   -1.4317   -1.6536    0.3913
# TCGA-B7-A5TI   -1.6170   -1.0720   -0.4373   -0.8730   -0.9848   -0.5291
# ...                ...       ...       ...       ...       ...       ...
# TCGA-WY-A85A   -0.3775   -0.6975    0.0466   -1.2143    0.4425   -0.9402
# TCGA-WY-A85B   -0.1515    0.5935    0.3402   -0.2231    0.3485   -0.8402
# TCGA-WY-A85C    0.3284    0.7869    0.9922    0.9422    1.0692   -0.4389
# TCGA-WY-A85D   -1.2386   -1.1186    0.6909   -1.2143   -0.1277   -0.6813
# TCGA-WY-A85E   -0.3137   -0.3742   -2.4513    1.1519    0.7383   -0.3227
#
#               23140.0   26009.0
# TCGA-3M-AB46   -1.6618    0.2748
# TCGA-3M-AB47   -0.0619    0.5492
# TCGA-B7-5816   -0.3589   -1.4745
# TCGA-B7-5818   -1.5988   -2.7521
# TCGA-B7-A5TI   -0.6019    0.0214
# ...                ...       ...
# TCGA-WY-A85A   -0.1893    0.4236
# TCGA-WY-A85B    0.1042    1.0122
# TCGA-WY-A85C    0.7413    1.2262
# TCGA-WY-A85D   -0.5001    0.8035
# TCGA-WY-A85E   -0.4875    0.2730
#
# [2763 rows x 20502 columns]

# %%
# 백업용
third_df=second_df.copy()

# cna_dfset에 Cancer 열 추가
third_df['Cancer'] = ''

# clinical 데이터프레임을 순회하며 cna_dfset에 값 할당
for index, row in third_df.iterrows():
    for i, pat in clinical.iterrows():
        if(index==pat['PATIENT_ID']):
            cancer_type = pat['CANCER_TYPE_ACRONYM']
            third_df.at[index, 'Cancer'] = cancer_type
            break
third_df
# Out:
#                  1.0  29974.0  54715.0  87769.0     2.0  144568.0  53947.0  \
# TCGA-3M-AB46  0.2076  -1.0518  -0.8329   1.2071 -0.7818   -0.8253  -0.9673
# TCGA-3M-AB47  0.4276   0.5072   2.1122   0.6262  0.9275   -0.6354   0.4636
# TCGA-B7-5816 -0.9922  -2.1072  -1.0945   0.3858 -0.4149   -0.4633   1.1193
# TCGA-B7-5818 -1.0179  -2.1278  -1.0945  -2.6991 -1.2313    0.8780  -0.5319
# TCGA-B7-A5TI -0.4527   0.6810  -1.0945   0.8135  0.4039    0.6896  -0.0799
# ...              ...      ...      ...      ...     ...       ...      ...
# TCGA-WY-A85A  0.0365  -2.3298   0.0690  -0.0906 -0.3067    0.9726  -0.7398
# TCGA-WY-A85B  0.1544  -2.3298  -0.8346   0.0154  0.8500   -0.8925  -1.0079
# TCGA-WY-A85C  0.6591  -0.2885  -0.8072  -0.3613 -0.0253   -0.9871   0.1267
# TCGA-WY-A85D  1.8078  -2.3298  -1.1571  -0.9304  0.0875    0.8196  -0.3884
# TCGA-WY-A85E  0.6973  -2.3298   0.8931  -1.1419 -1.1735    0.4283  -1.5843
#
#               51146.0  404744.0  8086.0  ...  11130.0  7789.0  158586.0  \
# TCGA-3M-AB46  -1.5546    0.7883  0.0646  ...   2.6983 -1.0061   -0.4243
# TCGA-3M-AB47  -1.0286   -1.4886 -0.5795  ...  -0.5029 -1.1278    0.6149
# TCGA-B7-5816   0.3950   -0.7351 -0.6825  ...   0.1416 -0.0425   -0.9111
# TCGA-B7-5818   1.9559   -1.4886 -0.0726  ...   0.7458 -2.5996   -5.5211
# TCGA-B7-A5TI   1.5994   -0.1381  0.0263  ...   1.0328 -1.6170   -1.0720
# ...               ...       ...     ...  ...      ...     ...       ...
# TCGA-WY-A85A  -0.6719   -1.3060  0.8323  ...  -0.4914 -0.3775   -0.6975
# TCGA-WY-A85B   0.9052   -1.3060 -0.0945  ...   1.1282 -0.1515    0.5935
# TCGA-WY-A85C   0.3564   -1.3060  0.8454  ...  -0.7663  0.3284    0.7869
# TCGA-WY-A85D  -1.8299   -1.3060  0.9347  ...  -0.3125 -1.2386   -1.1186
# TCGA-WY-A85E  -1.8299   -0.5086  0.4441  ...   1.1751 -0.3137   -0.3742
#
#               79364.0  440590.0  79699.0  7791.0  23140.0  26009.0  Cancer
# TCGA-3M-AB46  -1.1151    0.6274   0.5821 -0.8533  -1.6618   0.2748    STAD
# TCGA-3M-AB47  -0.7507   -0.5807   0.3698 -0.1465  -0.0619   0.5492    STAD
# TCGA-B7-5816  -1.1933   -1.4317  -0.8969 -0.0919  -0.3589  -1.4745    STAD
# TCGA-B7-5818   1.3570   -1.4317  -1.6536  0.3913  -1.5988  -2.7521    STAD
# TCGA-B7-A5TI  -0.4373   -0.8730  -0.9848 -0.5291  -0.6019   0.0214    STAD
# ...               ...       ...      ...     ...      ...      ...     ...
# TCGA-WY-A85A   0.0466   -1.2143   0.4425 -0.9402  -0.1893   0.4236     LGG
# TCGA-WY-A85B   0.3402   -0.2231   0.3485 -0.8402   0.1042   1.0122     LGG
# TCGA-WY-A85C   0.9922    0.9422   1.0692 -0.4389   0.7413   1.2262     LGG
# TCGA-WY-A85D   0.6909   -1.2143  -0.1277 -0.6813  -0.5001   0.8035     LGG
# TCGA-WY-A85E  -2.4513    1.1519   0.7383 -0.3227  -0.4875   0.2730     LGG
#
# [2763 rows x 20503 columns]

# %%
#만일 Cancer에 값이 안들어간 경우 해당 행은 제외
fourth_df = third_df[third_df['Cancer'] != '']
fourth_df
# Out:
#                  1.0  29974.0  54715.0  87769.0     2.0  144568.0  53947.0  \
# TCGA-3M-AB46  0.2076  -1.0518  -0.8329   1.2071 -0.7818   -0.8253  -0.9673
# TCGA-3M-AB47  0.4276   0.5072   2.1122   0.6262  0.9275   -0.6354   0.4636
# TCGA-B7-5816 -0.9922  -2.1072  -1.0945   0.3858 -0.4149   -0.4633   1.1193
# TCGA-B7-5818 -1.0179  -2.1278  -1.0945  -2.6991 -1.2313    0.8780  -0.5319
# TCGA-B7-A5TI -0.4527   0.6810  -1.0945   0.8135  0.4039    0.6896  -0.0799
# ...              ...      ...      ...      ...     ...       ...      ...
# TCGA-WY-A85A  0.0365  -2.3298   0.0690  -0.0906 -0.3067    0.9726  -0.7398
# TCGA-WY-A85B  0.1544  -2.3298  -0.8346   0.0154  0.8500   -0.8925  -1.0079
# TCGA-WY-A85C  0.6591  -0.2885  -0.8072  -0.3613 -0.0253   -0.9871   0.1267
# TCGA-WY-A85D  1.8078  -2.3298  -1.1571  -0.9304  0.0875    0.8196  -0.3884
# TCGA-WY-A85E  0.6973  -2.3298   0.8931  -1.1419 -1.1735    0.4283  -1.5843
#
#               51146.0  404744.0  8086.0  ...  11130.0  7789.0  158586.0  \
# TCGA-3M-AB46  -1.5546    0.7883  0.0646  ...   2.6983 -1.0061   -0.4243
# TCGA-3M-AB47  -1.0286   -1.4886 -0.5795  ...  -0.5029 -1.1278    0.6149
# TCGA-B7-5816   0.3950   -0.7351 -0.6825  ...   0.1416 -0.0425   -0.9111
# TCGA-B7-5818   1.9559   -1.4886 -0.0726  ...   0.7458 -2.5996   -5.5211
# TCGA-B7-A5TI   1.5994   -0.1381  0.0263  ...   1.0328 -1.6170   -1.0720
# ...               ...       ...     ...  ...      ...     ...       ...
# TCGA-WY-A85A  -0.6719   -1.3060  0.8323  ...  -0.4914 -0.3775   -0.6975
# TCGA-WY-A85B   0.9052   -1.3060 -0.0945  ...   1.1282 -0.1515    0.5935
# TCGA-WY-A85C   0.3564   -1.3060  0.8454  ...  -0.7663  0.3284    0.7869
# TCGA-WY-A85D  -1.8299   -1.3060  0.9347  ...  -0.3125 -1.2386   -1.1186
# TCGA-WY-A85E  -1.8299   -0.5086  0.4441  ...   1.1751 -0.3137   -0.3742
#
#               79364.0  440590.0  79699.0  7791.0  23140.0  26009.0  Cancer
# TCGA-3M-AB46  -1.1151    0.6274   0.5821 -0.8533  -1.6618   0.2748    STAD
# TCGA-3M-AB47  -0.7507   -0.5807   0.3698 -0.1465  -0.0619   0.5492    STAD
# TCGA-B7-5816  -1.1933   -1.4317  -0.8969 -0.0919  -0.3589  -1.4745    STAD
# TCGA-B7-5818   1.3570   -1.4317  -1.6536  0.3913  -1.5988  -2.7521    STAD
# TCGA-B7-A5TI  -0.4373   -0.8730  -0.9848 -0.5291  -0.6019   0.0214    STAD
# ...               ...       ...      ...     ...      ...      ...     ...
# TCGA-WY-A85A   0.0466   -1.2143   0.4425 -0.9402  -0.1893   0.4236     LGG
# TCGA-WY-A85B   0.3402   -0.2231   0.3485 -0.8402   0.1042   1.0122     LGG
# TCGA-WY-A85C   0.9922    0.9422   1.0692 -0.4389   0.7413   1.2262     LGG
# TCGA-WY-A85D   0.6909   -1.2143  -0.1277 -0.6813  -0.5001   0.8035     LGG
# TCGA-WY-A85E  -2.4513    1.1519   0.7383 -0.3227  -0.4875   0.2730     LGG
#
# [1962 rows x 20503 columns]

# %%
#데이터를 0으로 변겅하는 프로세스
fifth_df = fourth_df.fillna(0)
fifth_df
# Out:
#                  1.0  29974.0  54715.0  87769.0     2.0  144568.0  53947.0  \
# TCGA-3M-AB46  0.2076  -1.0518  -0.8329   1.2071 -0.7818   -0.8253  -0.9673
# TCGA-3M-AB47  0.4276   0.5072   2.1122   0.6262  0.9275   -0.6354   0.4636
# TCGA-B7-5816 -0.9922  -2.1072  -1.0945   0.3858 -0.4149   -0.4633   1.1193
# TCGA-B7-5818 -1.0179  -2.1278  -1.0945  -2.6991 -1.2313    0.8780  -0.5319
# TCGA-B7-A5TI -0.4527   0.6810  -1.0945   0.8135  0.4039    0.6896  -0.0799
# ...              ...      ...      ...      ...     ...       ...      ...
# TCGA-WY-A85A  0.0365  -2.3298   0.0690  -0.0906 -0.3067    0.9726  -0.7398
# TCGA-WY-A85B  0.1544  -2.3298  -0.8346   0.0154  0.8500   -0.8925  -1.0079
# TCGA-WY-A85C  0.6591  -0.2885  -0.8072  -0.3613 -0.0253   -0.9871   0.1267
# TCGA-WY-A85D  1.8078  -2.3298  -1.1571  -0.9304  0.0875    0.8196  -0.3884
# TCGA-WY-A85E  0.6973  -2.3298   0.8931  -1.1419 -1.1735    0.4283  -1.5843
#
#               51146.0  404744.0  8086.0  ...  11130.0  7789.0  158586.0  \
# TCGA-3M-AB46  -1.5546    0.7883  0.0646  ...   2.6983 -1.0061   -0.4243
# TCGA-3M-AB47  -1.0286   -1.4886 -0.5795  ...  -0.5029 -1.1278    0.6149
# TCGA-B7-5816   0.3950   -0.7351 -0.6825  ...   0.1416 -0.0425   -0.9111
# TCGA-B7-5818   1.9559   -1.4886 -0.0726  ...   0.7458 -2.5996   -5.5211
# TCGA-B7-A5TI   1.5994   -0.1381  0.0263  ...   1.0328 -1.6170   -1.0720
# ...               ...       ...     ...  ...      ...     ...       ...
# TCGA-WY-A85A  -0.6719   -1.3060  0.8323  ...  -0.4914 -0.3775   -0.6975
# TCGA-WY-A85B   0.9052   -1.3060 -0.0945  ...   1.1282 -0.1515    0.5935
# TCGA-WY-A85C   0.3564   -1.3060  0.8454  ...  -0.7663  0.3284    0.7869
# TCGA-WY-A85D  -1.8299   -1.3060  0.9347  ...  -0.3125 -1.2386   -1.1186
# TCGA-WY-A85E  -1.8299   -0.5086  0.4441  ...   1.1751 -0.3137   -0.3742
#
#               79364.0  440590.0  79699.0  7791.0  23140.0  26009.0  Cancer
# TCGA-3M-AB46  -1.1151    0.6274   0.5821 -0.8533  -1.6618   0.2748    STAD
# TCGA-3M-AB47  -0.7507   -0.5807   0.3698 -0.1465  -0.0619   0.5492    STAD
# TCGA-B7-5816  -1.1933   -1.4317  -0.8969 -0.0919  -0.3589  -1.4745    STAD
# TCGA-B7-5818   1.3570   -1.4317  -1.6536  0.3913  -1.5988  -2.7521    STAD
# TCGA-B7-A5TI  -0.4373   -0.8730  -0.9848 -0.5291  -0.6019   0.0214    STAD
# ...               ...       ...      ...     ...      ...      ...     ...
# TCGA-WY-A85A   0.0466   -1.2143   0.4425 -0.9402  -0.1893   0.4236     LGG
# TCGA-WY-A85B   0.3402   -0.2231   0.3485 -0.8402   0.1042   1.0122     LGG
# TCGA-WY-A85C   0.9922    0.9422   1.0692 -0.4389   0.7413   1.2262     LGG
# TCGA-WY-A85D   0.6909   -1.2143  -0.1277 -0.6813  -0.5001   0.8035     LGG
# TCGA-WY-A85E  -2.4513    1.1519   0.7383 -0.3227  -0.4875   0.2730     LGG
#
# [1962 rows x 20503 columns]

# %%
testval = fifth_df.isin(['MARCH11']).any().any()
testval
# Out:
# False

# %%
fifth_df.isnull().sum()
# Out:
# 1.0        0
# 29974.0    0
# 54715.0    0
# 87769.0    0
# 2.0        0
#           ..
# 79699.0    0
# 7791.0     0
# 23140.0    0
# 26009.0    0
# Cancer     0
# Length: 20503, dtype: int64

# %%
X = fifth_df.drop("Cancer", axis=1)
y = fifth_df["Cancer"]

# %%
X
# Out:
#               1.0       29974.0   54715.0   87769.0   2.0       144568.0  \
# TCGA-3M-AB46    0.2076   -1.0518   -0.8329    1.2071   -0.7818   -0.8253
# TCGA-3M-AB47    0.4276    0.5072    2.1122    0.6262    0.9275   -0.6354
# TCGA-B7-5816   -0.9922   -2.1072   -1.0945    0.3858   -0.4149   -0.4633
# TCGA-B7-5818   -1.0179   -2.1278   -1.0945   -2.6991   -1.2313    0.8780
# TCGA-B7-A5TI   -0.4527    0.6810   -1.0945    0.8135    0.4039    0.6896
# ...                ...       ...       ...       ...       ...       ...
# TCGA-WY-A85A    0.0365   -2.3298    0.0690   -0.0906   -0.3067    0.9726
# TCGA-WY-A85B    0.1544   -2.3298   -0.8346    0.0154    0.8500   -0.8925
# TCGA-WY-A85C    0.6591   -0.2885   -0.8072   -0.3613   -0.0253   -0.9871
# TCGA-WY-A85D    1.8078   -2.3298   -1.1571   -0.9304    0.0875    0.8196
# TCGA-WY-A85E    0.6973   -2.3298    0.8931   -1.1419   -1.1735    0.4283
#
#               53947.0   51146.0   404744.0  8086.0    ...  55055.0   11130.0   \
# TCGA-3M-AB46   -0.9673   -1.5546    0.7883    0.0646  ...    1.2552    2.6983
# TCGA-3M-AB47    0.4636   -1.0286   -1.4886   -0.5795  ...    0.1266   -0.5029
# TCGA-B7-5816    1.1193    0.3950   -0.7351   -0.6825  ...   -0.9013    0.1416
# TCGA-B7-5818   -0.5319    1.9559   -1.4886   -0.0726  ...   -1.4085    0.7458
# TCGA-B7-A5TI   -0.0799    1.5994   -0.1381    0.0263  ...    0.3886    1.0328
# ...                ...       ...       ...       ...  ...       ...       ...
# TCGA-WY-A85A   -0.7398   -0.6719   -1.3060    0.8323  ...   -0.5834   -0.4914
# TCGA-WY-A85B   -1.0079    0.9052   -1.3060   -0.0945  ...    1.0486    1.1282
# TCGA-WY-A85C    0.1267    0.3564   -1.3060    0.8454  ...   -0.6817   -0.7663
# TCGA-WY-A85D   -0.3884   -1.8299   -1.3060    0.9347  ...   -1.9247   -0.3125
# TCGA-WY-A85E   -1.5843   -1.8299   -0.5086    0.4441  ...    0.8830    1.1751
#
#               7789.0    158586.0  79364.0   440590.0  79699.0   7791.0    \
# TCGA-3M-AB46   -1.0061   -0.4243   -1.1151    0.6274    0.5821   -0.8533
# TCGA-3M-AB47   -1.1278    0.6149   -0.7507   -0.5807    0.3698   -0.1465
# TCGA-B7-5816   -0.0425   -0.9111   -1.1933   -1.4317   -0.8969   -0.0919
# TCGA-B7-5818   -2.5996   -5.5211    1.3570   -1.4317   -1.6536    0.3913
# TCGA-B7-A5TI   -1.6170   -1.0720   -0.4373   -0.8730   -0.9848   -0.5291
# ...                ...       ...       ...       ...       ...       ...
# TCGA-WY-A85A   -0.3775   -0.6975    0.0466   -1.2143    0.4425   -0.9402
# TCGA-WY-A85B   -0.1515    0.5935    0.3402   -0.2231    0.3485   -0.8402
# TCGA-WY-A85C    0.3284    0.7869    0.9922    0.9422    1.0692   -0.4389
# TCGA-WY-A85D   -1.2386   -1.1186    0.6909   -1.2143   -0.1277   -0.6813
# TCGA-WY-A85E   -0.3137   -0.3742   -2.4513    1.1519    0.7383   -0.3227
#
#               23140.0   26009.0
# TCGA-3M-AB46   -1.6618    0.2748
# TCGA-3M-AB47   -0.0619    0.5492
# TCGA-B7-5816   -0.3589   -1.4745
# TCGA-B7-5818   -1.5988   -2.7521
# TCGA-B7-A5TI   -0.6019    0.0214
# ...                ...       ...
# TCGA-WY-A85A   -0.1893    0.4236
# TCGA-WY-A85B    0.1042    1.0122
# TCGA-WY-A85C    0.7413    1.2262
# TCGA-WY-A85D   -0.5001    0.8035
# TCGA-WY-A85E   -0.4875    0.2730
#
# [1962 rows x 20502 columns]

# %%
y
# Out:
# TCGA-3M-AB46    STAD
# TCGA-3M-AB47    STAD
# TCGA-B7-5816    STAD
# TCGA-B7-5818    STAD
# TCGA-B7-A5TI    STAD
#                 ...
# TCGA-WY-A85A     LGG
# TCGA-WY-A85B     LGG
# TCGA-WY-A85C     LGG
# TCGA-WY-A85D     LGG
# TCGA-WY-A85E     LGG
# Name: Cancer, Length: 1962, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=500)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
final_model = LogisticRegression(max_iter=400)
final_model.fit(X, y)
# Out:
# LogisticRegression(max_iter=400)

# %%
#train, test split해서 학습시킨 model로 점수 구하였을 때...
from sklearn.metrics import accuracy_score
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 1.0

# %%
y_pred
# Out:
# array(['STAD', 'COAD', 'COAD', 'LUAD', 'LUAD', 'STAD', 'COAD', 'STAD',
#        'STAD', 'LGG', 'LIHC', 'LUAD', 'LUAD', 'LGG', 'STAD', 'STAD',
#        'LGG', 'LIHC', 'LIHC', 'COAD', 'LIHC', 'COAD', 'LIHC', 'LIHC',
#        'LIHC', 'COAD', 'STAD', 'STAD', 'LIHC', 'LIHC', 'LGG', 'STAD',
#        'LIHC', 'LGG', 'SKCM', 'LUAD', 'LGG', 'LIHC', 'STAD', 'LUAD',
#        'LGG', 'LUAD', 'LIHC', 'LIHC', 'LUAD', 'STAD', 'LGG', 'LGG', 'LGG',
#        'LUAD', 'COAD', 'LUAD', 'STAD', 'LIHC', 'LUAD', 'LUAD', 'LGG',
#        'LGG', 'LUAD', 'LUAD', 'STAD', 'STAD', 'STAD', 'LUAD', 'LUAD',
#        'LGG', 'LUAD', 'LUAD', 'LGG', 'LIHC', 'COAD', 'STAD', 'STAD',
#        'COAD', 'LUAD', 'LGG', 'LGG', 'LUAD', 'LGG', 'LGG', 'LGG', 'LGG',
#        'LIHC', 'LUAD', 'LIHC', 'COAD', 'LUAD', 'LUAD', 'LIHC', 'LGG',
#        'COAD', 'LIHC', 'LUAD', 'LGG', 'LGG', 'COAD', 'COAD', 'LUAD',
#        'COAD', 'COAD', 'LGG', 'LUAD', 'COAD', 'LGG', 'STAD', 'LUAD',
#        'LGG', 'LGG', 'STAD', 'STAD', 'LIHC', 'LUAD', 'LUAD', 'LGG', 'LGG',
#        'COAD', 'LUAD', 'LIHC', 'LGG', 'LGG', 'COAD', 'COAD', 'COAD',
#        'LIHC', 'LIHC', 'LUAD', 'LGG', 'LUAD', 'LUAD', 'LGG', 'LUAD',
#        'LUAD', 'LGG', 'LUAD', 'LGG', 'LUAD', 'STAD', 'LIHC', 'STAD',
#        'LUAD', 'LIHC', 'STAD', 'LUAD', 'COAD', 'COAD', 'LGG', 'LGG',
#        'LUAD', 'LGG', 'LIHC', 'LGG', 'LIHC', 'LIHC', 'LGG', 'STAD',
#        'STAD', 'LUAD', 'STAD', 'COAD', 'STAD', 'LUAD', 'COAD', 'STAD',
#        'LIHC', 'STAD', 'COAD', 'LGG', 'STAD', 'COAD', 'LIHC', 'STAD',
#        'LGG', 'LGG', 'LIHC', 'LIHC', 'LUAD', 'STAD', 'LGG', 'LUAD',
#        'STAD', 'LGG', 'STAD', 'LIHC', 'COAD', 'LGG', 'LGG', 'STAD',
#        'LUAD', 'COAD', 'LGG', 'LIHC', 'LIHC', 'LGG', 'LIHC', 'LIHC',
#        'STAD', 'STAD', 'STAD', 'LGG', 'STAD', 'LUAD', 'LGG', 'LGG',
#        'LUAD', 'LGG', 'COAD', 'STAD', 'COAD', 'LGG', 'LGG', 'STAD',
#        'LUAD', 'LUAD', 'LIHC', 'LUAD', 'LGG', 'LIHC', 'STAD', 'LUAD',
#        'SKCM', 'LGG', 'COAD', 'LGG', 'LGG', 'LIHC', 'LUAD', 'COAD',
#        'STAD', 'LGG', 'STAD', 'LIHC', 'LGG', 'LUAD', 'COAD', 'LUAD',
#        'LUAD', 'LUAD', 'COAD', 'LGG', 'LUAD', 'COAD', 'COAD', 'LIHC',
#        'LUAD', 'SKCM', 'STAD', 'LUAD', 'COAD', 'LUAD', 'LUAD', 'LUAD',
#        'STAD', 'LGG', 'COAD', 'COAD', 'LIHC', 'COAD', 'STAD', 'COAD',
#        'COAD', 'STAD', 'LGG', 'LIHC', 'LUAD', 'LUAD', 'COAD', 'LUAD',
#        'LUAD', 'STAD', 'LUAD', 'LUAD', 'COAD', 'LGG', 'LUAD', 'LGG',
#        'COAD', 'LIHC', 'LGG', 'STAD', 'SKCM', 'LUAD', 'STAD', 'STAD',
#        'LIHC', 'STAD', 'LGG', 'LGG', 'STAD', 'COAD', 'LIHC', 'STAD',
#        'STAD', 'LGG', 'COAD', 'LIHC', 'LIHC', 'COAD', 'STAD', 'LIHC',
#        'LUAD', 'COAD', 'LIHC', 'LGG', 'LUAD', 'STAD', 'STAD', 'LUAD',
#        'STAD', 'LGG', 'LGG', 'LIHC', 'STAD', 'COAD', 'STAD', 'LUAD',
#        'LGG', 'LGG', 'LGG', 'LGG', 'LGG', 'STAD', 'LUAD', 'LGG', 'LUAD',
#        'COAD', 'LIHC', 'STAD', 'LUAD', 'LGG', 'SKCM', 'SKCM', 'LGG',
#        'LGG', 'COAD', 'STAD', 'LIHC', 'COAD', 'LIHC', 'LIHC', 'SKCM',
#        'COAD', 'LIHC', 'COAD', 'COAD', 'STAD', 'LIHC', 'COAD', 'COAD',
#        'LGG', 'COAD', 'COAD', 'LGG', 'STAD', 'COAD', 'LIHC', 'LGG', 'LGG',
#        'LUAD', 'LUAD', 'COAD', 'STAD', 'LIHC', 'LGG', 'COAD', 'LUAD',
#        'COAD', 'COAD', 'LUAD', 'LGG', 'LIHC', 'LUAD', 'LIHC', 'LIHC',
#        'COAD', 'LIHC', 'LGG', 'LIHC', 'LIHC', 'LGG', 'STAD', 'STAD',
#        'LGG', 'LUAD', 'LGG', 'LUAD', 'COAD', 'LIHC', 'LGG', 'LIHC',
#        'LUAD', 'COAD', 'LUAD', 'LIHC'], dtype=object)

# %% [markdown]
# ### 여기서부터는 테스트 데이터 결과 도출입니다

# %%
test_rna_df = pd.read_csv("./testData/test_data_rna-seq_v1.csv", encoding='utf-8')
test_rna_df
# Out:
#       Hugo_Symbol  Entrez_Gene_Id  patient_34  patient_35  patient_5  \
# 0             NaN       100130426         NaN         NaN        NaN
# 1             NaN       100133144      0.0313     -1.1888    -0.6275
# 2             NaN       100134869     -1.9899      0.0618    -0.6568
# 3             NaN           10357      0.8538     -1.4139    -1.6290
# 4             NaN           10431      0.0726     -1.4780    -1.4820
# ...           ...             ...         ...         ...        ...
# 20526      ZYG11A          440590     -1.4317      1.1030    -0.6893
# 20527      ZYG11B           79699     -0.4268     -1.1815    -0.9811
# 20528         ZYX            7791     -0.0860      0.4660     0.7733
# 20529       ZZEF1           23140     -0.2940     -1.3591    -1.4425
# 20530        ZZZ3           26009     -0.0350     -0.9253    -0.7750
#
#        patient_65  patient_7  patient_8  patient_9  patient_1  ...  \
# 0             NaN        NaN        NaN        NaN        NaN  ...
# 1         -2.8225    -0.9355     0.2755    -0.5159    -3.6531  ...
# 2         -2.0187    -0.2693     1.4479     1.0652    -1.2866  ...
# 3         -1.6207    -2.0586    -1.8798    -0.6720    -0.8844  ...
# 4          0.1970    -1.0236     0.1647     0.5723     1.0053  ...
# ...           ...        ...        ...        ...        ...  ...
# 20526     -0.3313    -1.0208    -1.4317    -0.2368     1.8149  ...
# 20527     -1.2863    -0.3284    -1.4403    -1.2965     0.7038  ...
# 20528      1.8049     1.3232     0.5540    -0.2708     1.1159  ...
# 20529      0.3220     0.5374    -2.5013    -0.5578    -0.3484  ...
# 20530     -1.9503    -0.6608     0.2970    -0.2962    -0.4009  ...
#
#        patient_52  patient_53  patient_54  patient_28  patient_68  patient_57  \
# 0         -6.6197     -6.6197     -6.6197     -6.6197     -6.6197     -6.6197
# 1         -0.0104     -0.4469     -0.2674     -1.4728     -1.1543     -0.0359
# 2         -0.6447     -0.7510     -0.4568     -0.9079     -0.1149     -0.9998
# 3          0.2089      1.8635      1.5797      0.0796      0.3014      0.0396
# 4          0.3580      0.8525      0.2391      0.5402      0.6718      0.2211
# ...           ...         ...         ...         ...         ...         ...
# 20526      0.6812     -0.3444     -1.2143     -1.2143     -0.1383     -0.5836
# 20527     -0.0309      1.1275      0.8424      0.6774      1.8079     -1.3332
# 20528     -1.1755     -0.5240     -1.6614     -0.2644     -0.6075      0.5624
# 20529     -0.8474     -0.8440      0.0883      0.2331     -2.0918     -1.0157
# 20530      1.0964      0.8055      1.8831      0.4670      0.4043      0.6091
#
#        patient_58  patient_59  patient_72  patient_61
# 0         -6.6197     -6.6197     -6.6197     -6.6197
# 1         -3.1094     -0.7935     -3.1094     -1.4103
# 2         -0.6871      0.8822     -0.4106      0.4940
# 3         -1.1425     -0.5699     -0.2267      0.2357
# 4          2.4127      0.6833     -0.5026      1.6788
# ...           ...         ...         ...         ...
# 20526     -0.0645     -0.6352      0.5606     -1.2143
# 20527     -3.6953     -0.6294     -0.7373     -2.0814
# 20528      1.3264     -0.5177     -0.3267      0.6660
# 20529     -0.9135     -0.4802     -1.3742     -1.6413
# 20530     -4.3633     -1.3504      0.0142     -2.1100
#
# [20531 rows x 76 columns]

# %%
#Nan제거
test_rna_df = test_rna_df.dropna(subset=['Hugo_Symbol'])
test_rna_df = test_rna_df.reset_index(drop=True)
test_rna_df
# Out:
#       Hugo_Symbol  Entrez_Gene_Id  patient_34  patient_35  patient_5  \
# 0            A1BG               1     -0.7970     -1.4861     0.1948
# 1            A1CF           29974     -1.6064     -0.5171     0.7332
# 2           A2BP1           54715     -1.0945     -1.0945    -0.8868
# 3           A2LD1           87769     -0.4542     -0.2880    -0.2676
# 4             A2M               2      0.4107      0.4235     0.8486
# ...           ...             ...         ...         ...        ...
# 20497      ZYG11A          440590     -1.4317      1.1030    -0.6893
# 20498      ZYG11B           79699     -0.4268     -1.1815    -0.9811
# 20499         ZYX            7791     -0.0860      0.4660     0.7733
# 20500       ZZEF1           23140     -0.2940     -1.3591    -1.4425
# 20501        ZZZ3           26009     -0.0350     -0.9253    -0.7750
#
#        patient_65  patient_7  patient_8  patient_9  patient_1  ...  \
# 0          1.3791     0.8012    -1.3639    -1.2248     0.3409  ...
# 1          0.6536     0.5584    -0.2447     0.2907        NaN  ...
# 2         -0.4227     0.9259    -0.9107    -0.9458        NaN  ...
# 3          0.4978     0.5735    -0.5469     0.3127    -0.4666  ...
# 4          1.6071     1.6144     0.1215    -0.5271     1.5034  ...
# ...           ...        ...        ...        ...        ...  ...
# 20497     -0.3313    -1.0208    -1.4317    -0.2368     1.8149  ...
# 20498     -1.2863    -0.3284    -1.4403    -1.2965     0.7038  ...
# 20499      1.8049     1.3232     0.5540    -0.2708     1.1159  ...
# 20500      0.3220     0.5374    -2.5013    -0.5578    -0.3484  ...
# 20501     -1.9503    -0.6608     0.2970    -0.2962    -0.4009  ...
#
#        patient_52  patient_53  patient_54  patient_28  patient_68  patient_57  \
# 0          0.2190     -2.0785     -0.4279     -1.4864     -0.4417      0.9471
# 1         -2.3298     -2.3298     -2.3298     -2.3298      0.0101     -2.3298
# 2         -0.8648      0.5075      0.0062      0.0683      1.6677      0.1720
# 3         -0.3464     -0.0686      0.1903     -0.1848     -0.1319      0.9772
# 4          0.8221      0.7054      0.0560      1.7167     -0.9979      0.2529
# ...           ...         ...         ...         ...         ...         ...
# 20497      0.6812     -0.3444     -1.2143     -1.2143     -0.1383     -0.5836
# 20498     -0.0309      1.1275      0.8424      0.6774      1.8079     -1.3332
# 20499     -1.1755     -0.5240     -1.6614     -0.2644     -0.6075      0.5624
# 20500     -0.8474     -0.8440      0.0883      0.2331     -2.0918     -1.0157
# 20501      1.0964      0.8055      1.8831      0.4670      0.4043      0.6091
#
#        patient_58  patient_59  patient_72  patient_61
# 0         -0.7556      0.1781      0.9657      0.3516
# 1         -2.3298     -2.3298      3.1993     -2.3298
# 2         -0.3173      0.1840     -0.3776     -0.9338
# 3         -0.5544     -0.8007      1.8816      1.4004
# 4          1.2668     -0.9036      0.1425     -0.4349
# ...           ...         ...         ...         ...
# 20497     -0.0645     -0.6352      0.5606     -1.2143
# 20498     -3.6953     -0.6294     -0.7373     -2.0814
# 20499      1.3264     -0.5177     -0.3267      0.6660
# 20500     -0.9135     -0.4802     -1.3742     -1.6413
# 20501     -4.3633     -1.3504      0.0142     -2.1100
#
# [20502 rows x 76 columns]

# %%
test_rna_set = test_rna_df.drop(['Hugo_Symbol'],axis=1)

test_rna_set=test_rna_set.transpose()

test_rna_set = test_rna_set.rename(columns=test_rna_set.iloc[0])

test_rna_set = test_rna_set.drop(test_rna_set.index[0])
test_rna_set
# Out:
#             1.0       29974.0   54715.0   87769.0   2.0       144568.0  \
# patient_34   -0.7970   -1.6064   -1.0945   -0.4542    0.4107    0.4798
# patient_35   -1.4861   -0.5171   -1.0945   -0.2880    0.4235   -0.8253
# patient_5     0.1948    0.7332   -0.8868   -0.2676    0.8486   -0.7489
# patient_65    1.3791    0.6536   -0.4227    0.4978    1.6071   -0.8253
# patient_7     0.8012    0.5584    0.9259    0.5735    1.6144    0.8943
# ...              ...       ...       ...       ...       ...       ...
# patient_57    0.9471   -2.3298    0.1720    0.9772    0.2529    1.5292
# patient_58   -0.7556   -2.3298   -0.3173   -0.5544    1.2668   -1.4734
# patient_59    0.1781   -2.3298    0.1840   -0.8007   -0.9036    0.5082
# patient_72    0.9657    3.1993   -0.3776    1.8816    0.1425    1.9203
# patient_61    0.3516   -2.3298   -0.9338    1.4004   -0.4349    0.5836
#
#             53947.0   51146.0   404744.0  8086.0    ...  55055.0   11130.0   \
# patient_34   -0.4802   -1.1262   -1.4886   -0.6607  ...    0.6668    0.1833
# patient_35    1.1270   -0.3289   -1.4886   -0.2843  ...   -1.4181   -1.4764
# patient_5     0.8944    2.0952   -1.4886   -0.5063  ...   -1.1046   -0.9107
# patient_65    1.9917   -1.1048   -1.4886    1.0861  ...   -2.2675   -0.4971
# patient_7     1.2996    0.6000   -0.8817   -0.5246  ...   -0.8591   -0.4480
# ...              ...       ...       ...       ...  ...       ...       ...
# patient_57    0.0796   -1.8299   -1.3060   -0.8843  ...    0.0831   -0.9160
# patient_58    2.3380   -1.8299   -1.3060    2.0684  ...   -0.4510    1.2286
# patient_59   -0.3016   -1.8299   -0.4040    0.6352  ...   -1.9418   -0.5863
# patient_72    0.2481   -0.7041   -1.3060   -0.5267  ...   -0.8721   -2.1572
# patient_61    0.8949    0.8527   -1.3060    0.3456  ...   -1.2811   -1.0375
#
#             7789.0    158586.0  79364.0   440590.0  79699.0   7791.0    \
# patient_34   -0.2432   -0.3486    0.1757   -1.4317   -0.4268   -0.0860
# patient_35    0.4286   -0.2136   -0.4854    1.1030   -1.1815    0.4660
# patient_5     0.4796    0.2064   -0.6044   -0.6893   -0.9811    0.7733
# patient_65    0.8220   -0.0229   -0.5947   -0.3313   -1.2863    1.8049
# patient_7     0.3806   -0.2777   -0.7029   -1.0208   -0.3284    1.3232
# ...              ...       ...       ...       ...       ...       ...
# patient_57   -1.0609   -0.9301    0.3490   -0.5836   -1.3332    0.5624
# patient_58   -1.5066   -1.0752   -0.7429   -0.0645   -3.6953    1.3264
# patient_59   -0.5323    0.0291    0.1092   -0.6352   -0.6294   -0.5177
# patient_72   -1.5062   -1.5347   -0.2171    0.5606   -0.7373   -0.3267
# patient_61   -1.4347   -1.0483   -0.2544   -1.2143   -2.0814    0.6660
#
#             23140.0   26009.0
# patient_34   -0.2940   -0.0350
# patient_35   -1.3591   -0.9253
# patient_5    -1.4425   -0.7750
# patient_65    0.3220   -1.9503
# patient_7     0.5374   -0.6608
# ...              ...       ...
# patient_57   -1.0157    0.6091
# patient_58   -0.9135   -4.3633
# patient_59   -0.4802   -1.3504
# patient_72   -1.3742    0.0142
# patient_61   -1.6413   -2.1100
#
# [74 rows x 20502 columns]

# %%
#데이터를 0으로 변겅하는 프로세스
test_rna_set = test_rna_set.fillna(0)
test_rna_set
# Out:
#             1.0       29974.0   54715.0   87769.0   2.0       144568.0  \
# patient_34   -0.7970   -1.6064   -1.0945   -0.4542    0.4107    0.4798
# patient_35   -1.4861   -0.5171   -1.0945   -0.2880    0.4235   -0.8253
# patient_5     0.1948    0.7332   -0.8868   -0.2676    0.8486   -0.7489
# patient_65    1.3791    0.6536   -0.4227    0.4978    1.6071   -0.8253
# patient_7     0.8012    0.5584    0.9259    0.5735    1.6144    0.8943
# ...              ...       ...       ...       ...       ...       ...
# patient_57    0.9471   -2.3298    0.1720    0.9772    0.2529    1.5292
# patient_58   -0.7556   -2.3298   -0.3173   -0.5544    1.2668   -1.4734
# patient_59    0.1781   -2.3298    0.1840   -0.8007   -0.9036    0.5082
# patient_72    0.9657    3.1993   -0.3776    1.8816    0.1425    1.9203
# patient_61    0.3516   -2.3298   -0.9338    1.4004   -0.4349    0.5836
#
#             53947.0   51146.0   404744.0  8086.0    ...  55055.0   11130.0   \
# patient_34   -0.4802   -1.1262   -1.4886   -0.6607  ...    0.6668    0.1833
# patient_35    1.1270   -0.3289   -1.4886   -0.2843  ...   -1.4181   -1.4764
# patient_5     0.8944    2.0952   -1.4886   -0.5063  ...   -1.1046   -0.9107
# patient_65    1.9917   -1.1048   -1.4886    1.0861  ...   -2.2675   -0.4971
# patient_7     1.2996    0.6000   -0.8817   -0.5246  ...   -0.8591   -0.4480
# ...              ...       ...       ...       ...  ...       ...       ...
# patient_57    0.0796   -1.8299   -1.3060   -0.8843  ...    0.0831   -0.9160
# patient_58    2.3380   -1.8299   -1.3060    2.0684  ...   -0.4510    1.2286
# patient_59   -0.3016   -1.8299   -0.4040    0.6352  ...   -1.9418   -0.5863
# patient_72    0.2481   -0.7041   -1.3060   -0.5267  ...   -0.8721   -2.1572
# patient_61    0.8949    0.8527   -1.3060    0.3456  ...   -1.2811   -1.0375
#
#             7789.0    158586.0  79364.0   440590.0  79699.0   7791.0    \
# patient_34   -0.2432   -0.3486    0.1757   -1.4317   -0.4268   -0.0860
# patient_35    0.4286   -0.2136   -0.4854    1.1030   -1.1815    0.4660
# patient_5     0.4796    0.2064   -0.6044   -0.6893   -0.9811    0.7733
# patient_65    0.8220   -0.0229   -0.5947   -0.3313   -1.2863    1.8049
# patient_7     0.3806   -0.2777   -0.7029   -1.0208   -0.3284    1.3232
# ...              ...       ...       ...       ...       ...       ...
# patient_57   -1.0609   -0.9301    0.3490   -0.5836   -1.3332    0.5624
# patient_58   -1.5066   -1.0752   -0.7429   -0.0645   -3.6953    1.3264
# patient_59   -0.5323    0.0291    0.1092   -0.6352   -0.6294   -0.5177
# patient_72   -1.5062   -1.5347   -0.2171    0.5606   -0.7373   -0.3267
# patient_61   -1.4347   -1.0483   -0.2544   -1.2143   -2.0814    0.6660
#
#             23140.0   26009.0
# patient_34   -0.2940   -0.0350
# patient_35   -1.3591   -0.9253
# patient_5    -1.4425   -0.7750
# patient_65    0.3220   -1.9503
# patient_7     0.5374   -0.6608
# ...              ...       ...
# patient_57   -1.0157    0.6091
# patient_58   -0.9135   -4.3633
# patient_59   -0.4802   -1.3504
# patient_72   -1.3742    0.0142
# patient_61   -1.6413   -2.1100
#
# [74 rows x 20502 columns]

# %%
#환자1부터 차례대로 있게 하는것
test_rna_set = test_rna_set.iloc[test_rna_set.index.astype(str).str.extract('(\d+)').astype(int).sort_values(by=0).index]
test_rna_set
# Out:
#             1.0       29974.0   54715.0   87769.0   2.0       144568.0  \
# patient_1     0.3409    0.0000    0.0000   -0.4666    1.5034   -0.8245
# patient_2    -0.6584   -0.9931   -0.8520   -0.2783    0.6657   -0.5695
# patient_3    -0.4427    0.7887   -1.0359    0.1624    0.1326   -1.5105
# patient_4    -1.0651    0.8219   -1.0359    1.2859   -1.9703   -1.5105
# patient_5     0.1948    0.7332   -0.8868   -0.2676    0.8486   -0.7489
# ...              ...       ...       ...       ...       ...       ...
# patient_70   -0.0754   -1.2801   -0.4983   -0.0559   -1.1749   -0.9136
# patient_71   -0.3020   -1.2801   -0.9874   -1.0931   -1.8139   -0.9136
# patient_72    0.9657    3.1993   -0.3776    1.8816    0.1425    1.9203
# patient_73    0.1144    0.6345   -0.9874    0.7102    0.4054    0.1779
# patient_74    0.2473   -1.2801   -0.9874    0.0998    0.5455    0.1368
#
#             53947.0   51146.0   404744.0  8086.0    ...  55055.0   11130.0   \
# patient_1     1.3905   -0.2116    0.0000   -0.1563  ...   -0.7690   -0.1299
# patient_2    -0.8448   -0.3670   -0.0778   -0.3129  ...   -0.0649   -0.0885
# patient_3     0.9635   -1.1665    1.5832    0.5078  ...    1.2754    1.3721
# patient_4    -1.3483   -1.1665   -1.5794    0.0386  ...    1.3948    1.0977
# patient_5     0.8944    2.0952   -1.4886   -0.5063  ...   -1.1046   -0.9107
# ...              ...       ...       ...       ...  ...       ...       ...
# patient_70    1.4859   -0.0936   -4.6136    0.6735  ...    1.4717    1.9149
# patient_71   -0.4788    0.2504   -4.6136    0.7004  ...    1.3178    0.9137
# patient_72    0.2481   -0.7041   -1.3060   -0.5267  ...   -0.8721   -2.1572
# patient_73   -0.6599   -0.3626   -4.6136    2.3964  ...   -2.2624   -0.7311
# patient_74    0.8420   -1.8249   -4.6136   -0.5217  ...   -0.3875   -0.4860
#
#             7789.0    158586.0  79364.0   440590.0  79699.0   7791.0    \
# patient_1     0.1915   -0.1904   -1.1761    1.8149    0.7038    1.1159
# patient_2    -0.8805   -0.5958    0.5515    0.3507    0.3513   -0.1165
# patient_3     1.2591    1.9395    1.5085    1.7182    2.0320    0.1193
# patient_4     2.1222    0.8577    2.7827    0.4183    0.8452   -2.0517
# patient_5     0.4796    0.2064   -0.6044   -0.6893   -0.9811    0.7733
# ...              ...       ...       ...       ...       ...       ...
# patient_70   -1.2712   -0.5375   -1.5697   -0.4334   -0.7383    1.5243
# patient_71   -0.8435    0.6213   -0.8221    1.9176    0.6194    0.9272
# patient_72   -1.5062   -1.5347   -0.2171    0.5606   -0.7373   -0.3267
# patient_73   -1.5147   -1.2047   -2.3282   -0.1411   -0.7221    0.8746
# patient_74    0.2175    1.1372    0.1300   -0.3672    0.1264    0.2018
#
#             23140.0   26009.0
# patient_1    -0.3484   -0.4009
# patient_2    -0.2731    0.0095
# patient_3     0.9679    1.0774
# patient_4     1.1303    0.4846
# patient_5    -1.4425   -0.7750
# ...              ...       ...
# patient_70   -1.5691   -0.6089
# patient_71   -2.2363   -0.6841
# patient_72   -1.3742    0.0142
# patient_73   -0.7372   -3.0246
# patient_74   -0.5116   -0.2690
#
# [74 rows x 20502 columns]

# %%
test_pred = final_model.predict(test_rna_set)

# %%
test_pred
# Out:
# array(['STAD', 'LUAD', 'LIHC', 'LIHC', 'STAD', 'LIHC', 'STAD', 'STAD',
#        'STAD', 'LUAD', 'LUAD', 'LUAD', 'SKCM', 'SKCM', 'LUAD', 'COAD',
#        'LUAD', 'STAD', 'LUAD', 'LUAD', 'LIHC', 'LUAD', 'LUAD', 'LIHC',
#        'LUAD', 'LIHC', 'LIHC', 'LGG', 'LIHC', 'LIHC', 'COAD', 'LIHC',
#        'LIHC', 'STAD', 'STAD', 'LIHC', 'COAD', 'COAD', 'COAD', 'COAD',
#        'LUAD', 'COAD', 'LGG', 'SKCM', 'LUAD', 'COAD', 'COAD', 'LGG',
#        'LGG', 'SKCM', 'LGG', 'LGG', 'LGG', 'LGG', 'LIHC', 'COAD', 'LGG',
#        'LGG', 'LGG', 'COAD', 'LGG', 'SKCM', 'SKCM', 'SKCM', 'STAD',
#        'SKCM', 'SKCM', 'LGG', 'LUAD', 'SKCM', 'SKCM', 'LGG', 'SKCM',
#        'SKCM'], dtype=object)

# %%
data = {'id': ['patient_' + str(i) for i in range(1, len(test_pred)+1)],
        'expected': test_pred}

df = pd.DataFrame(data)
df.to_csv('rna_predictions.csv', index=False)

# %% [markdown]
# ### 데이터 학습에 영향을 끼친 column 찾기

# %%
# 회귀 계수 출력
coef = final_model.coef_
print(coef[0])
# Out:
# [ 0.00180909  0.00106825 -0.00162253 ... -0.00029034 -0.00076311
#   0.00016087]

# %%
feature_importance = abs(model.coef_[0])
most_influential_column_index = np.argmax(feature_importance)
most_influential_column = X_train.columns[most_influential_column_index]
print("Most influential column:", most_influential_column)
# Out:
# Most influential column: 390321.0

# %%
feature_importance = abs(model.coef_[1])
most_influential_column_index = np.argmax(feature_importance)
most_influential_column = X_train.columns[most_influential_column_index]
print("Most influential column 2st:", most_influential_column)
# Out:
# Most influential column 2st: 403278.0

# %%
feature_importance = abs(model.coef_[2])
most_influential_column_index = np.argmax(feature_importance)
most_influential_column = X_train.columns[most_influential_column_index]
print("Most influential column 3st:", most_influential_column)
# Out:
# Most influential column 3st: 641451.0
